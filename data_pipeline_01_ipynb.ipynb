# %% [markdown]
# <a href="https://colab.research.google.com/github/SADAT334/Travelbuddy-AI/blob/main/data_pipeline_01_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# TravelBuddy AI – Data Pipeline 01
Objective:
- Collect and clean travel data
- Build reusable datasets
